# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
raw = datasets.load_diabetes(as_frame=True)
import pandas as pd
df = pd.DataFrame(raw.data)
df.head()
diabetes_X= df[['BMI']].values
diabetes_Y= df['target'].values
plt.plot[diabetes_X,diabetes_Y]
plt.scatter(diabetes_X,diabetes_Y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-404583316.py in <cell line: 0>()
#       8 df = pd.DataFrame(raw.data)
#       9 df.head()
# ---> 10 diabetes_X= df(['BMI']).values
#      11 diabetes_Y= df['target'].values
#      12 plt.plot[diabetes_X,diabetes_Y]
#
# TypeError: 'DataFrame' object is not callable

# %%
Load Diabete Dataset

# %%
raw = datasets.load_diabetes(as_frame=True)
import pandas as pd
df = pd.DataFrame(raw.data)
df.head()
diabetes_X=df['BMI']
diabetes_Y=df['target']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BMI'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2853686552.py in <cell line: 0>()
#       3 df = pd.DataFrame(raw.data)
#       4 df.head()
# ----> 5 diabetes_X=df['BMI']
#       6 diabetes_Y=df['target']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'BMI'
